# %% [markdown]
# <a href="https://colab.research.google.com/github/likitha-mindi/CODSOFT/blob/main/CODSOFT_AI_TASK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.chat.util import Chat, reflections

# Define patterns and responses
pairs = [
    [
        r"hi|hello|hey",
        ["Hello! How can I help you today?", "Hi there! What can I do for you?"]
    ],
    [
        r"what is your name ?",
        ["My name is Chatbot. I am an NLP based bot."]
    ],
    [
        r"how are you ?",
        ["I'm doing great! Thanks for asking."]
    ],
    [
        r"sorry (.*)",
        ["No problem", "It's okay"]
    ],
    [
        r"(.*) help (.*)",
        ["Sure, I will try to help you."]
    ],
    [
        r"quit",
        ["Bye! Have a great day."]
    ],
]

# Create chatbot
chatbot = Chat(pairs, reflections)

print("NLP Chatbot: Hi! Type 'quit' to exit.")
chatbot.converse()
# Out:
# NLP Chatbot: Hi! Type 'quit' to exit.
# >hello
# Hi there! What can I do for you?
# >How are you
# I'm doing great! Thanks for asking.
# >quit
# Bye! Have a great day.
